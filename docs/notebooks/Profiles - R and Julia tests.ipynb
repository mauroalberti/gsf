# %% [markdown]
# # Geologic profiles with pygsf

# %% [markdown]
# *Doc started 2019-05-12*
#
# *Current version: 2019-09-14*

# %% [markdown]
# This notebook describes the calculation of topographic profiles. As input data we need a DEM and a profile.

# %% [markdown]
# Figures are plotted via matplotlib:

# %%
# %matplotlib inline

# %% [markdown]
# Data sets can be plotted with pprint:

# %%
from pprint import pprint

# %% [markdown]
# ## 1-  Mount Alpi (Lucania, Southern Italy)

# %% [markdown]
# ### DEM input

# %% [markdown]
# The source DEM derives from publicly available Aster data and refers to the the Mt. Alpi zone (Lucania, Southern Italy):

# %%
source_data = "/home/mauro/Documents/projects/gsf/example_data/mt_alpi/malpi_aster_w4u3.tif"

# %% [markdown]
# We read the DEM using a wrapper function to GDAL:

# %%
from pygsf.spatial.rasters.io import read_raster_band
success, result = read_raster_band(raster_source=source_data, epsg_cd = 32633)
if success:
    geoarray = result

# %% [markdown]
# The DEM projection is UTM zone 33 N. We plot it.

# %%
from pygsf.utils.maps.plot import plot_grid
fig = plot_grid(geoarray)

# %% [markdown]
# ### Source profile

# %% [markdown]
# Now we read the source profile from a line shapefile. It is a single line, projected in WGS 84 - UTM 33 N.

# %%
src_profile_shapefile_pth = "/home/mauro/Documents/projects/gsf/example_data/mt_alpi/profile.shp"

# %%
from pygsf.spatial.vectorial.io import read_linestring_geometries
profiles = read_linestring_geometries(src_profile_shapefile_pth)
print(profiles)
# Out:
# MultiLine with 1 line(s) and 2 total point(s) - EPSG: 32633

# %% [markdown]
# This *MultiLine* instance contains a single line, that is made up by two points.
# The spatial reference of the line profile is the same as the raster DEM: WGS1984 - UTM 33 N.
# So no projection conversion is required to calculate the profile.

# %% [markdown]
# Now we extract the profile line and add it in the previous map.

# %%
line = profiles.line()
from pygsf.utils.maps.plot import plot_line
plot_line(fig, line)

# %% [markdown]
# ### Initializing a geoprofile

# %% [markdown]
# The *geoprofile* is the unitary container for our topographic and geological data related to a single geological profiles. It is initialized as an empty geoprofile, to which content will be added in subsequent steps.

# %%
from pygsf.spatial.geology.profiles.geoprofiles import GeoProfile
geoprofile = GeoProfile()

# %% [markdown]
# ### Creating a linear profiler

# %% [markdown]
# To extract the topographic and geologic elements from the various data source, we make use of the *linear profiler*.
# The data extracted will then be added to the *geoprofile*.
#
# We generate a *linear profiler*, with a spacing of 5 meters along the profile, by making use of the *LinearProfiler* class in the *geoprocess* module.

# %%
from pygsf.spatial.geology.profiles.profilers import LinearProfiler
profiler = LinearProfiler(start_pt=line.start_pt(), end_pt=line.end_pt(), densify_distance= 5)

# %%
profiler
# Out:
# LinearProfiler(
# 	start_pt = Point(581981.1880, 4442999.2144, 0.0000, 0.0000, 32633),
# 	end_pt = Point(586203.5723, 4440126.1905, 0.0000, 0.0000, 32633),
# 	densify_distance = 5.0)

# %%
profiler.num_pts()
# Out:
# 1023

# %% [markdown]
# The number of points making up the profile is slightly more than a thousand.

# %% [markdown]
# ### Adding a topographic profile

# %% [markdown]
# Now we create and plot a vertical topographic profile using as elevation data source the previously defined DEM.

# %%
topo_profile = profiler.profile_grid(geoarray)
print("Type of 'topo_profile': {}".format(type(topo_profile)))
# Out:
# Type of 'topo_profile': <class 'pygsf.spatial.geology.profiles.chains.TopographicProfile'>

# %% [markdown]
# The variable *topo_profile* is an instance of <*geoprocess.profiles.base.ScalarProfiles*>.
# The *Scalar* prefix to *Profiles* means that scalar values (f.i., elevations) are stored in the profile(s).
#
# Since we used just one grid as a parameter for the *profile_grids* method, there is a single topographic profile stored in the variable.

# %% [markdown]
# Now we add the topographic profile to the geological profile:

# %%
geoprofile.topo_profile = topo_profile

# %% [markdown]
# And then plot it:

# %%
from pygsf.spatial.geology.profiles.plot import plot
fig = plot(geoprofile)
# Out:
# Making topography

# %% [markdown]
# ### Geological attitudes plot

# %% [markdown]
# We extract geological attitudes from a shapefile:

# %%
attitudes_shape = "/home/mauro/Documents/projects/gsf/example_data/mt_alpi/attitudes.shp"

# %% [markdown]
# We use the *geopandas* module to read the data. It will create a *geopandas.GeoDataFrame* instance.

# %%
import geopandas
attitudes = geopandas.read_file(attitudes_shape)
attitudes
# Out:
#     Id  dip_dir  dip_ang                            Formation            type  \
# 0    1     90.0     18.0                  Mesozoic limestones  stratification
# 1    2     95.0     30.0               Miocenic conglomerates  stratification
# 2    3     72.0     26.0                Miocenic calcarenites  stratification
# 3    4     75.0     40.0                  Mesozoic limestones  stratification
# 4    5     80.0     15.0                  Mesozoic limestones  stratification
# 5    6     60.0     25.0                Miocenic calcarenites  stratification
# 6    7     30.0     15.0                  Mesozoic limestones  stratification
# 7    8     70.0     35.0                  Mesozoic limestones  stratification
# 8    9    105.0     40.0                  Mesozoic limestones  stratification
# 9   10    135.0     21.0  Miocenic arenites and conglomerates  stratification
# 10  11     80.0     30.0                  Mesozoic limestones  stratification
#
#                           geometry
# 0   POINT (583531.375 4441614.401)
# 1   POINT (583771.704 4441895.090)
# 2   POINT (584184.366 4441269.220)
# 3   POINT (584722.156 4441071.520)
# 4   POINT (582878.687 4442105.863)
# 5   POINT (584266.849 4441208.758)
# 6   POINT (584249.684 4441182.484)
# 7   POINT (584838.631 4440925.733)
# 8   POINT (584644.096 4441353.934)
# 9   POINT (585641.114 4440448.176)
# 10  POINT (585200.730 4441084.297)

# %%
attitudes.crs
# Out:
# {'init': 'epsg:32633'}

# %% [markdown]
# The projection of the source dataset is UTM33, as are the DEM and the profile, so we do not need any reprojection.

# %%
ax = attitudes.plot()

# %% [markdown]
# We get the relevant infos from the geodataframe. We do not provide any name for the id field name in the *extract_georeferenced_attitudes* function, so the id will be simple a progressive counter. Otherwise the id would be red by the provided field name.

# %%
from pygsf.spatial.geology.convert import extract_georeferenced_attitudes
attitudes = extract_georeferenced_attitudes(
    geodataframe = attitudes, 
    azim_fldnm = "dip_dir", 
    dip_ang_fldnm = "dip_ang")
# Out:
# Source crs: {'init': 'epsg:32633'}
# Extracted EPSG code: 32633

# %%
print("Number of attitudes: {}".format(len(attitudes)))
# Out:
# Number of attitudes: 11

# %%
pprint(attitudes)
# Out:
# [GeorefAttitude(id=1, posit=Point(583531.3753, 4441614.4005, 0.0000, 0.0000, 32633), attitude=Plane(090.00, +18.00)),
#  GeorefAttitude(id=2, posit=Point(583771.7042, 4441895.0901, 0.0000, 0.0000, 32633), attitude=Plane(095.00, +30.00)),
#  GeorefAttitude(id=3, posit=Point(584184.3662, 4441269.2196, 0.0000, 0.0000, 32633), attitude=Plane(072.00, +26.00)),
#  GeorefAttitude(id=4, posit=Point(584722.1560, 4441071.5204, 0.0000, 0.0000, 32633), attitude=Plane(075.00, +40.00)),
#  GeorefAttitude(id=5, posit=Point(582878.6869, 4442105.8626, 0.0000, 0.0000, 32633), attitude=Plane(080.00, +15.00)),
#  GeorefAttitude(id=6, posit=Point(584266.8488, 4441208.7581, 0.0000, 0.0000, 32633), attitude=Plane(060.00, +25.00)),
#  GeorefAttitude(id=7, posit=Point(584249.6836, 4441182.4839, 0.0000, 0.0000, 32633), attitude=Plane(030.00, +15.00)),
#  GeorefAttitude(id=8, posit=Point(584838.6306, 4440925.7328, 0.0000, 0.0000, 32633), attitude=Plane(070.00, +35.00)),
#  GeorefAttitude(id=9, posit=Point(584644.0965, 4441353.9335, 0.0000, 0.0000, 32633), attitude=Plane(105.00, +40.00)),
#  GeorefAttitude(id=10, posit=Point(585641.1138, 4440448.1764, 0.0000, 0.0000, 32633), attitude=Plane(135.00, +21.00)),
#  GeorefAttitude(id=11, posit=Point(585200.7298, 4441084.2967, 0.0000, 0.0000, 32633), attitude=Plane(080.00, +30.00))]

# %% [markdown]
# A georeferenced attitude is defined by its *id*, *postion* and *attitude*. We note that the points are 2D, since their elevation value, i.e., their third Cartesian coordinate, is always zero (the fourth coordinate is time and the last is the EPSG numeric code). Their elevation will be automatically extracted from the DEM in the following steps by choosing a *height_source* parameter in the *map_georef_attitudes_to_section* method.

# %% [markdown]
# Having converted the data in a suitable format (i.e., *GeorefAttitude*), now we calculate the projections of the attitude on the section:

# %%
mapping_method = {}
mapping_method['method'] = 'nearest'
att_projs = profiler.map_georef_attitudes_to_section(
            structural_data = attitudes,
            mapping_method = mapping_method,
            height_source = geoarray)
# Out:
# Profile attitude: ProfileAttitude(id=1, s=2048.1696666709017, z=1719.0523705180385, slope_degr=15.036461412285021, down_sense=right, dist=277.07059293755856, src_dip_dir=90.0, src_dip_ang=18.0)
# Profile attitude: ProfileAttitude(id=2, s=2112.1540235549446, z=1778.1549344889354, slope_degr=26.739985134228576, down_sense=right, dist=97.35582649748838, src_dip_dir=95.0, src_dip_ang=30.0)
# Profile attitude: ProfileAttitude(id=3, s=2774.5313396243873, z=1565.4636538076447, slope_degr=16.631758453194006, down_sense=right, dist=203.50319812472765, src_dip_dir=72.0, src_dip_ang=26.0)
# Profile attitude: ProfileAttitude(id=4, s=3336.6810534354227, z=1672.2149600663688, slope_degr=28.71945528113712, down_sense=right, dist=59.31261092056573, src_dip_dir=75.0, src_dip_ang=40.0)
# Profile attitude: ProfileAttitude(id=5, s=1236.4861872424606, z=1572.5213765137596, slope_degr=10.867965575312148, down_sense=right, dist=237.6050261383221, src_dip_dir=80.0, src_dip_ang=15.0)
# Profile attitude: ProfileAttitude(id=6, s=2881.0196828011162, z=1557.8591956259916, slope_degr=11.459372574286705, down_sense=right, dist=210.30767756509084, src_dip_dir=60.0, src_dip_ang=25.0)
# Profile attitude: ProfileAttitude(id=7, s=2898.7039708295083, z=1533.092653978907, slope_degr=1.1328961144174967, down_sense=left, dist=233.78088130040757, src_dip_dir=30.0, src_dip_ang=15.0)
# Profile attitude: ProfileAttitude(id=8, s=3507.5914422029373, z=1574.9798849619692, slope_degr=22.25782849945163, down_sense=right, dist=120.68469869444648, src_dip_dir=70.0, src_dip_ang=35.0)
# Profile attitude: ProfileAttitude(id=9, s=3145.682021481595, z=1650.3363548688358, slope_degr=38.388714168301426, down_sense=right, dist=140.9625488932911, src_dip_dir=105.0, src_dip_ang=40.0)
# Profile attitude: ProfileAttitude(id=10, s=4462.167436033904, z=1169.3611732347636, slope_degr=20.661729902414084, down_sense=right, dist=50.31883288721889, src_dip_dir=135.0, src_dip_ang=21.0)
# Profile attitude: ProfileAttitude(id=11, s=3771.467569093934, z=1606.1862184682395, slope_degr=22.47393430497033, down_sense=right, dist=243.25126669583346, src_dip_dir=80.0, src_dip_ang=30.0)

# %%
pprint(att_projs)
# Out:
# [ProfileAttitude(id=5, s=1236.4861872424606, z=1572.5213765137596, slope_degr=10.867965575312148, down_sense=right, dist=237.6050261383221, src_dip_dir=80.0, src_dip_ang=15.0),
#  ProfileAttitude(id=1, s=2048.1696666709017, z=1719.0523705180385, slope_degr=15.036461412285021, down_sense=right, dist=277.07059293755856, src_dip_dir=90.0, src_dip_ang=18.0),
#  ProfileAttitude(id=2, s=2112.1540235549446, z=1778.1549344889354, slope_degr=26.739985134228576, down_sense=right, dist=97.35582649748838, src_dip_dir=95.0, src_dip_ang=30.0),
#  ProfileAttitude(id=3, s=2774.5313396243873, z=1565.4636538076447, slope_degr=16.631758453194006, down_sense=right, dist=203.50319812472765, src_dip_dir=72.0, src_dip_ang=26.0),
#  ProfileAttitude(id=6, s=2881.0196828011162, z=1557.8591956259916, slope_degr=11.459372574286705, down_sense=right, dist=210.30767756509084, src_dip_dir=60.0, src_dip_ang=25.0),
#  ProfileAttitude(id=7, s=2898.7039708295083, z=1533.092653978907, slope_degr=1.1328961144174967, down_sense=left, dist=233.78088130040757, src_dip_dir=30.0, src_dip_ang=15.0),
#  ProfileAttitude(id=9, s=3145.682021481595, z=1650.3363548688358, slope_degr=38.388714168301426, down_sense=right, dist=140.9625488932911, src_dip_dir=105.0, src_dip_ang=40.0),
#  ProfileAttitude(id=4, s=3336.6810534354227, z=1672.2149600663688, slope_degr=28.71945528113712, down_sense=right, dist=59.31261092056573, src_dip_dir=75.0, src_dip_ang=40.0),
#  ProfileAttitude(id=8, s=3507.5914422029373, z=1574.9798849619692, slope_degr=22.25782849945163, down_sense=right, dist=120.68469869444648, src_dip_dir=70.0, src_dip_ang=35.0),
#  ProfileAttitude(id=11, s=3771.467569093934, z=1606.1862184682395, slope_degr=22.47393430497033, down_sense=right, dist=243.25126669583346, src_dip_dir=80.0, src_dip_ang=30.0),
#  ProfileAttitude(id=10, s=4462.167436033904, z=1169.3611732347636, slope_degr=20.661729902414084, down_sense=right, dist=50.31883288721889, src_dip_dir=135.0, src_dip_ang=21.0)]

# %% [markdown]
# Resulting profile attitudes are automatically sorted by their increasing distance along the profile. The main fields are:
# - *id*: identifier inherited from the georeferenced attitudes,
# - *s*: the distance of the projected attitude along the profile (may be negative or exceeed the profile length),
# - *z*: the elevation,
# - *slope_degr*: the resulting slope, in degrees,
# - *down_sense*: describes whether the plane plunges to the right or to the left,
# - *dist*: the distance between the original attitude location and its projection (according to the chosen method) on the profile plane.

# %%
geoprofile.attitudes = att_projs

# %%
fig = plot(geoprofile)
# Out:
# Making topography

# %% [markdown]
# ## 2 - Timpa San Lorenzo area (Calabria, Southern Italy)

# %% [markdown]
# Now we move around 35 km to the South-East of the Mt. Alpi are, and consider the Timpa San Lorenzo area, in Calabria, East of Mt. Pollino range.

# %% [markdown]
# Source data are a TinItaly DEM, in addition to a base profile.

# %%
src_dem = "/home/mauro/Documents/projects/gsf/example_data/timpa_san_lorenzo/tsl_tinitaly_w84u32.tif"
src_profile = "/home/mauro/Documents/projects/gsf/example_data/timpa_san_lorenzo/profile.shp"

# %%
success, result = read_raster_band(
    raster_source=src_dem, 
    epsg_cd = 32632
)

if success:
    geoarray = result
    
fig = plot_grid(geoarray)

# %%
profiles = read_linestring_geometries(src_profile)
line = profiles.line()
plot_line(fig, line)

# %%
from pygsf.spatial.geology.profiles.geoprofiles import GeoProfileSet
geoprofiles = GeoProfileSet()
base_profiler = LinearProfiler(
    start_pt=line.start_pt(), 
    end_pt=line.end_pt(), 
    densify_distance= 5
)

# %%
base_profiler
# Out:
# LinearProfiler(
# 	start_pt = Point(1120743.2120, 4439367.3435, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1128114.1749, 4444681.2936, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)

# %%
base_profiler.num_pts()
# Out:
# 1819

# %%
from pygsf.spatial.geology.profiles.profilers import ParallelProfilers
multiple_profilers = ParallelProfilers.fromProfiler(
             base_profiler=base_profiler,
             profs_num=15,
             profs_offset=500,
             profs_arr="central")

# %%
multiple_profilers
# Out:
# ParallelProfilers([
# LinearProfiler(
# 	start_pt = Point(1118696.4064, 4442206.4608, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1126067.3694, 4447520.4109, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)
# LinearProfiler(
# 	start_pt = Point(1118988.8072, 4441800.8727, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1126359.7702, 4447114.8227, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)
# LinearProfiler(
# 	start_pt = Point(1119281.2080, 4441395.2845, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1126652.1710, 4446709.2345, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)
# LinearProfiler(
# 	start_pt = Point(1119573.6088, 4440989.6963, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1126944.5718, 4446303.6463, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)
# LinearProfiler(
# 	start_pt = Point(1119866.0096, 4440584.1081, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1127236.9726, 4445898.0581, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)
# LinearProfiler(
# 	start_pt = Point(1120158.4104, 4440178.5199, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1127529.3734, 4445492.4700, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)
# LinearProfiler(
# 	start_pt = Point(1120450.8112, 4439772.9317, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1127821.7742, 4445086.8818, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)
# LinearProfiler(
# 	start_pt = Point(1120743.2120, 4439367.3435, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1128114.1749, 4444681.2936, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)
# LinearProfiler(
# 	start_pt = Point(1121035.6127, 4438961.7553, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1128406.5757, 4444275.7054, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)
# LinearProfiler(
# 	start_pt = Point(1121328.0135, 4438556.1671, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1128698.9765, 4443870.1172, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)
# LinearProfiler(
# 	start_pt = Point(1121620.4143, 4438150.5790, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1128991.3773, 4443464.5290, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)
# LinearProfiler(
# 	start_pt = Point(1121912.8151, 4437744.9908, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1129283.7781, 4443058.9408, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)
# LinearProfiler(
# 	start_pt = Point(1122205.2159, 4437339.4026, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1129576.1789, 4442653.3526, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)
# LinearProfiler(
# 	start_pt = Point(1122497.6167, 4436933.8144, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1129868.5797, 4442247.7644, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)
# LinearProfiler(
# 	start_pt = Point(1122790.0175, 4436528.2262, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1130160.9805, 4441842.1763, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)]
# )

# %%
topo_profiles = multiple_profilers.profile_grid(geoarray)

# %%
print(type(topo_profiles))
# Out:
# <class 'pygsf.spatial.geology.profiles.sets.TopographicProfileSet'>

# %% [markdown]
# They constitute a TopographicProfileSet instance.

# %%
geoprofiles.topo_profiles_set = topo_profiles

# %%
fig = plot(geoprofiles)
# Out:
# Making topography
# Making topography
# Making topography
# Making topography
# Making topography
# Making topography
# Making topography
# Making topography
# Making topography
# Making topography
# Making topography
# Making topography
# Making topography
# Making topography
# Making topography

# %% [markdown]
# ### Line intersections

# %%
import geopandas
faults_shape = "/home/mauro/Documents/projects/gsf/example_data/timpa_san_lorenzo/faults.shp"
faults = geopandas.read_file(faults_shape)
faults
# Out:
#      fid                           name      type  \
# 0    1.0              Transversal fault  supposed
# 1    2.0              Transversal fault   certain
# 2    3.0              Transversal fault  supposed
# 3    4.0              Transversal fault   certain
# 4    6.0  Timpa San Lorenzo thrust flat   certain
# ..   ...                            ...       ...
# 74  76.0                         faglia      None
# 75  77.0                         faglia      None
# 76  78.0                         faglia      None
# 77  79.0                         faglia      None
# 78  80.0                         Faglia      None
#
#                                              geometry
# 0   LINESTRING (1117773.775 4446200.667, 1118716.8...
# 1   LINESTRING (1121723.500 4443752.009, 1121967.6...
# 2   LINESTRING (1125995.931 4440726.430, 1126367.9...
# 3   LINESTRING (1127696.184 4439627.805, 1128024.6...
# 4   LINESTRING (1122587.432 4446635.901, 1122594.6...
# ..                                                ...
# 74  LINESTRING (1109822.185 4446660.169, 1110871.5...
# 75  LINESTRING (1103874.440 4443780.246, 1104139.1...
# 76  LINESTRING (1130451.982 4435714.808, 1131255.5...
# 77  LINESTRING (1133068.375 4436116.602, 1132676.0...
# 78  LINESTRING (1099873.517 4461599.239, 1106756.0...
#
# [79 rows x 4 columns]

# %%
from pygsf.spatial.vectorial.io import try_read_line_shapefile

# %%
success, answer = try_read_line_shapefile(
    shp_path=faults_shape,
    flds=['fid', 'name'])

# %%
print(success)
# Out:
# True

# %%
results = answer

# %%
pprint(results)
# Out:
# [(Line with 6 points: (1117773.7747, 4446200.6667, 0.0000) ... (1121694.4355, 4443769.4478, 0.0000) - EPSG: 32632,
#   (1.0, 'Transversal fault')),
#  (Line with 16 points: (1121723.4997, 4443752.0093, 0.0000) ... (1125987.2119, 4440729.3367, 0.0000) - EPSG: 32632,
#   (2.0, 'Transversal fault')),
#  (Line with 7 points: (1125995.9311, 4440726.4303, 0.0000) ... (1127693.2780, 4439633.6179, 0.0000) - EPSG: 32632,
#   (3.0, 'Transversal fault')),
#  (Line with 2 points: (1127696.1844, 4439627.8051, 0.0000) ... (1128024.6095, 4439470.8586, 0.0000) - EPSG: 32632,
#   (4.0, 'Transversal fault')),
#  (Line with 9 points: (1122587.4318, 4446635.9005, 0.0000) ... (1122609.2299, 4446244.9876, 0.0000) - EPSG: 32632,
#   (6.0, 'Timpa San Lorenzo thrust flat')),
#  (Line with 15 points: (1122597.1523, 4446198.9284, 0.0000) ... (1122969.2622, 4445578.3284, 0.0000) - EPSG: 32632,
#   (7.0, 'Timpa San Lorenzo thrust flat')),
#  (Line with 9 points: (1107560.8980, 4448750.3182, 0.0000) ... (1107738.6435, 4449016.3460, 0.0000) - EPSG: 32632,
#   (8.0, 'Pollino minor fault')),
#  (Line with 7 points: (1107722.8399, 4448740.2365, 0.0000) ... (1107841.2763, 4448918.6178, 0.0000) - EPSG: 32632,
#   (9.0, 'Pollino minor fault')),
#  (Line with 9 points: (1123499.7739, 4444560.2654, 0.0000) ... (1124136.2790, 4443910.6815, 0.0000) - EPSG: 32632,
#   (10.0, 'Timpa San Lorenzo thrust flat')),
#  (Line with 25 points: (1123581.1536, 4444598.4121, 0.0000) ... (1125254.0684, 4441887.4527, 0.0000) - EPSG: 32632,
#   (11.0, 'Timpa San Lorenzo thrust flat')),
#  (Line with 21 points: (1125982.1256, 4440726.3395, 0.0000) ... (1126259.8433, 4438347.5446, 0.0000) - EPSG: 32632,
#   (12.0, 'Timpa San Lorenzo thrust flat')),
#  (Line with 6 points: (1126867.1293, 4435546.0163, 0.0000) ... (1126557.5960, 4435592.5190, 0.0000) - EPSG: 32632,
#   (13.0, 'Timpa San Lorenzo flat minor fault')),
#  (Line with 7 points: (1126782.4005, 4435581.1921, 0.0000) ... (1126770.1283, 4435195.3016, 0.0000) - EPSG: 32632,
#   (14.0, 'Timpa San Lorenzo thrust flat')),
#  (Line with 5 points: (1126835.5797, 4435199.3923, 0.0000) ... (1126561.5020, 4435193.9380, 0.0000) - EPSG: 32632,
#   (15.0, 'Timpa San Lorenzo flat minor fault')),
#  (Line with 4 points: (1126811.0355, 4435194.9607, 0.0000) ... (1126792.6273, 4435018.3782, 0.0000) - EPSG: 32632,
#   (16.0, 'Timpa San Lorenzo thrust flat')),
#  (Line with 6 points: (1126820.5805, 4435037.4682, 0.0000) ... (1126621.4991, 4434980.8800, 0.0000) - EPSG: 32632,
#   (17.0, 'Timpa San Lorenzo flat minor fault')),
#  (Line with 11 points: (1126813.0808, 4435028.6050, 0.0000) ... (1127426.0059, 4434574.5359, 0.0000) - EPSG: 32632,
#   (18.0, 'Timpa San Lorenzo thrust flat')),
#  (Line with 4 points: (1127443.0506, 4434579.9902, 0.0000) ... (1127324.4199, 4434492.0399, 0.0000) - EPSG: 32632,
#   (19.0, 'Timpa San Lorenzo flat minor fault')),
#  (Line with 6 points: (1127393.9620, 4434534.3106, 0.0000) ... (1127797.5790, 4434250.0061, 0.0000) - EPSG: 32632,
#   (20.0, 'Timpa San Lorenzo thrust flat')),
#  (Line with 8 points: (1121846.2740, 4447004.1660, 0.0000) ... (1122742.1400, 4446540.5519, 0.0000) - EPSG: 32632,
#   (21.0, 'Transversal fault')),
#  (Line with 10 points: (1122683.5065, 4446210.5678, 0.0000) ... (1121769.9140, 4446539.1884, 0.0000) - EPSG: 32632,
#   (22.0, 'Transversal fault')),
#  (Line with 9 points: (1122668.5072, 4446160.1157, 0.0000) ... (1121851.7283, 4446421.9213, 0.0000) - EPSG: 32632,
#   (23.0, 'Transversal fault')),
#  (Line with 10 points: (1121664.4921, 4446006.8981, 0.0000) ... (1123128.9110, 4445386.9541, 0.0000) - EPSG: 32632,
#   (24.0, 'Transversal fault')),
#  (Line with 6 points: (1122586.8018, 4445708.8741, 0.0000) ... (1122763.5705, 4445946.4264, 0.0000) - EPSG: 32632,
#   (25.0, 'Longitudinal fault')),
#  (Line with 6 points: (1122775.3550, 4445929.6799, 0.0000) ... (1122646.3449, 4445760.9744, 0.0000) - EPSG: 32632,
#   (26.0, 'Longitudinal fault')),
#  (Line with 10 points: (1122579.9791, 4445723.7599, 0.0000) ... (1122713.3309, 4446094.6641, 0.0000) - EPSG: 32632,
#   (27.0, 'Longitudinal fault')),
#  (Line with 7 points: (1122596.7256, 4445819.2770, 0.0000) ... (1122671.1545, 4446105.2082, 0.0000) - EPSG: 32632,
#   (28.0, 'Longitudinal fault')),
#  (Line with 8 points: (1122601.6875, 4445838.5045, 0.0000) ... (1122686.6606, 4446095.2843, 0.0000) - EPSG: 32632,
#   (29.0, 'Longitudinal fault')),
#  (Line with 6 points: (1122421.8176, 4445780.2018, 0.0000) ... (1122447.8677, 4445945.1860, 0.0000) - EPSG: 32632,
#   (30.0, 'Longitudinal fault')),
#  (Line with 8 points: (1122416.8557, 4445822.9985, 0.0000) ... (1122535.3217, 4446006.5898, 0.0000) - EPSG: 32632,
#   (31.0, 'Longitudinal fault')),
#  (Line with 7 points: (1122478.2596, 4445803.1508, 0.0000) ... (1122593.6244, 4446020.2351, 0.0000) - EPSG: 32632,
#   (32.0, 'Longitudinal fault')),
#  (Line with 7 points: (1121894.8072, 4447053.1001, 0.0000) ... (1122711.3195, 4446671.4926, 0.0000) - EPSG: 32632,
#   (33.0, 'Transversal fault')),
#  (Line with 2 points: (1122587.6701, 4446733.3173, 0.0000) ... (1122594.0658, 4446635.2505, 0.0000) - EPSG: 32632,
#   (34.0, 'Timpa San Lorenzo thrust flat')),
#  (Line with 2 points: (1122581.2744, 4446257.9067, 0.0000) ... (1122587.6701, 4446211.0052, 0.0000) - EPSG: 32632,
#   (35.0, 'Timpa San Lorenzo thrust flat')),
#  (Line with 26 points: (1126415.4710, 4438302.7750, 0.0000) ... (1126856.2302, 4435551.1026, 0.0000) - EPSG: 32632,
#   (36.0, 'Timpa San Lorenzo thrust flat')),
#  (Line with 3 points: (1126114.8751, 4438373.1272, 0.0000) ... (1126451.7131, 4438300.6431, 0.0000) - EPSG: 32632,
#   (37.0, 'Transversal fault')),
#  (Line with 5 points: (1125063.8554, 4436624.9809, 0.0000) ... (1124927.4147, 4437396.7235, 0.0000) - EPSG: 32632,
#   (38.0, 'Pollino top thrust')),
#  (Line with 14 points: (1124714.2262, 4437481.9990, 0.0000) ... (1123140.8945, 4439123.5510, 0.0000) - EPSG: 32632,
#   (39.0, 'Pollino top thrust')),
#  (Line with 13 points: (1122927.7059, 4439251.4642, 0.0000) ... (1121011.1406, 4439884.6342, 0.0000) - EPSG: 32632,
#   (40.0, 'Transversal fault')),
#  (Line with 9 points: (1121047.3826, 4439942.1951, 0.0000) ... (1120989.8217, 4440745.9161, 0.0000) - EPSG: 32632,
#   (41.0, 'Pollino top thrust')),
#  (Line with 6 points: (1120644.4562, 4440967.6322, 0.0000) ... (1120273.5081, 4440976.1597, 0.0000) - EPSG: 32632,
#   (42.0, 'Pollino top thrust')),
#  (Line with 7 points: (1117302.2585, 4445527.0721, 0.0000) ... (1119958.1458, 4449621.5650, 0.0000) - EPSG: 32632,
#   (43.0, 'Longitudinal fault')),
#  (Line with 10 points: (1117908.4936, 4446960.8663, 0.0000) ... (1115435.4392, 4448009.7493, 0.0000) - EPSG: 32632,
#   (44.0, 'Transversal fault')),
#  (Line with 5 points: (1122202.1217, 4443352.6458, 0.0000) ... (1122899.9602, 4443852.0469, 0.0000) - EPSG: 32632,
#   (45.0, 'Longitudinal fault')),
#  (Line with 8 points: (1123150.2583, 4443821.2668, 0.0000) ... (1122463.2310, 4443104.2238, 0.0000) - EPSG: 32632,
#   (46.0, 'Longitudinal fault')),
#  (Line with 7 points: (1123370.3738, 4440452.8320, 0.0000) ... (1125384.7646, 4439612.3908, 0.0000) - EPSG: 32632,
#   (47.0, 'Transversal fault')),
#  (Line with 6 points: (1124761.1039, 4437998.2101, 0.0000) ... (1125701.5976, 4437671.3719, 0.0000) - EPSG: 32632,
#   (48.0, 'Transversal fault')),
#  (Line with 7 points: (1124400.9148, 4437584.6597, 0.0000) ... (1125374.7594, 4437184.4496, 0.0000) - EPSG: 32632,
#   (49.0, 'Transversal fault')),
#  (Line with 4 points: (1127285.2483, 4433827.8494, 0.0000) ... (1126742.8254, 4433791.6879, 0.0000) - EPSG: 32632,
#   (50.0, 'faglia')),
#  (Line with 6 points: (1125683.5053, 4434400.0524, 0.0000) ... (1125998.3233, 4433693.8390, 0.0000) - EPSG: 32632,
#   (51.0, 'faglia')),
#  (Line with 6 points: (1127887.2314, 4434236.2620, 0.0000) ... (1126730.0625, 4434325.6022, 0.0000) - EPSG: 32632,
#   (52.0, 'faglia')),
#  (Line with 9 points: (1124500.7663, 4439959.1340, 0.0000) ... (1124913.7434, 4440842.9200, 0.0000) - EPSG: 32632,
#   (53.0, 'normale')),
#  (Line with 5 points: (1124696.7742, 4440118.6258, 0.0000) ... (1124789.3052, 4440667.4302, 0.0000) - EPSG: 32632,
#   (54.0, 'normale')),
#  (Line with 9 points: (1124428.7535, 4441238.5696, 0.0000) ... (1124082.4271, 4440115.1249, 0.0000) - EPSG: 32632,
#   (55.0, 'normale')),
#  (Line with 4 points: (1124065.0111, 4441066.2706, 0.0000) ... (1123860.8491, 4440178.9394, 0.0000) - EPSG: 32632,
#   (56.0, 'normale')),
#  (Line with 4 points: (1123889.5213, 4441915.0029, 0.0000) ... (1123379.0056, 4440491.9404, 0.0000) - EPSG: 32632,
#   (57.0, 'faglia')),
#  (Line with 7 points: (1117712.2814, 4442244.7110, 0.0000) ... (1116644.4528, 4442929.6529, 0.0000) - EPSG: 32632,
#   (58.0, 'faglia')),
#  (Line with 4 points: (1117678.2471, 4442172.3879, 0.0000) ... (1117197.5114, 4442444.6630, 0.0000) - EPSG: 32632,
#   (59.0, 'faglia')),
#  (Line with 6 points: (1117822.8932, 4442066.0305, 0.0000) ... (1120856.2072, 4440070.7650, 0.0000) - EPSG: 32632,
#   (60.0, 'faglia')),
#  (Line with 5 points: (1120651.4692, 4449996.5727, 0.0000) ... (1121312.4806, 4449821.6147, 0.0000) - EPSG: 32632,
#   (61.0, 'faglia')),
#  (Line with 6 points: (1120432.9046, 4449599.3276, 0.0000) ... (1121111.0662, 4450650.2721, 0.0000) - EPSG: 32632,
#   (62.0, 'faglia')),
#  (Line with 5 points: (1120481.2973, 4449687.6043, 0.0000) ... (1121334.8157, 4448843.1263, 0.0000) - EPSG: 32632,
#   (63.0, 'faglia')),
#  (Line with 3 points: (1120552.0250, 4449821.6147, 0.0000) ... (1120432.9046, 4450081.1268, 0.0000) - EPSG: 32632,
#   (64.0, 'faglia')),
#  (Line with 12 points: (1121213.5295, 4449825.9619, 0.0000) ... (1121291.8739, 4448879.4208, 0.0000) - EPSG: 32632,
#   (65.0, 'Timpa San Lorenzo thrust flat')),
#  (Line with 2 points: (1120479.1701, 4449964.6654, 0.0000) ... (1120582.3368, 4449872.1345, 0.0000) - EPSG: 32632,
#   (66.0, 'faglia')),
#  (Line with 4 points: (1122179.2937, 4444417.0616, 0.0000) ... (1121679.4138, 4443800.1885, 0.0000) - EPSG: 32632,
#   (67.0, 'faglia')),
#  (Line with 4 points: (1121762.5055, 4446007.7700, 0.0000) ... (1122054.9885, 4446385.3389, 0.0000) - EPSG: 32632,
#   (68.0, 'faglia')),
#  (Line with 4 points: (1121887.4755, 4446494.3553, 0.0000) ... (1121924.7006, 4446970.3048, 0.0000) - EPSG: 32632,
#   (69.0, 'faglia')),
#  (Line with 4 points: (1123481.5076, 4444599.8634, 0.0000) ... (1123220.9319, 4443810.1595, 0.0000) - EPSG: 32632,
#   (70.0, 'faglia')),
#  (Line with 13 points: (1106198.9413, 4448355.9797, 0.0000) ... (1110188.5269, 4447599.6601, 0.0000) - EPSG: 32632,
#   (71.0, 'faglia')),
#  (Line with 4 points: (1107579.2245, 4447821.8290, 0.0000) ... (1108827.1517, 4447481.4852, 0.0000) - EPSG: 32632,
#   (72.0, 'faglia')),
#  (Line with 3 points: (1113185.4431, 4446205.1960, 0.0000) ... (1113955.9436, 4445661.5913, 0.0000) - EPSG: 32632,
#   (73.0, 'faglia')),
#  (Line with 7 points: (1110755.7666, 4446814.9786, 0.0000) ... (1107040.3468, 4450757.2942, 0.0000) - EPSG: 32632,
#   (74.0, 'faglia')),
#  (Line with 4 points: (1109871.8181, 4445461.8757, 0.0000) ... (1116451.7981, 4442994.3832, 0.0000) - EPSG: 32632,
#   (75.0, 'faglia')),
#  (Line with 3 points: (1109822.1846, 4446660.1695, 0.0000) ... (1111672.8040, 4445334.2468, 0.0000) - EPSG: 32632,
#   (76.0, 'faglia')),
#  (Line with 4 points: (1103874.4405, 4443780.2464, 0.0000) ... (1104952.1958, 4442688.3101, 0.0000) - EPSG: 32632,
#   (77.0, 'faglia')),
#  (Line with 5 points: (1130451.9819, 4435714.8076, 0.0000) ... (1132848.5694, 4435053.0280, 0.0000) - EPSG: 32632,
#   (78.0, 'faglia')),
#  (Line with 5 points: (1133068.3748, 4436116.6023, 0.0000) ... (1131888.9890, 4436700.3865, 0.0000) - EPSG: 32632,
#   (79.0, 'faglia')),
#  (Line with 2 points: (1099873.5175, 4461599.2393, 0.0000) ... (1106756.0945, 4458741.2201, 0.0000) - EPSG: 32632,
#   (80.0, 'Faglia'))]

# %% [markdown]
# Here we check the type of the imported elements.

# %%
line_types = set(map(lambda val: type(val[0]), results))
print(line_types)
# Out:
# {<class 'pygsf.spatial.vectorial.geometries.Line'>}

# %% [markdown]
# They are all Line instances.

# %% [markdown]
# We filter the lines to be 'Timpa San Lorenzo thrust flat' elements.

# %%
from operator import itemgetter
tsl_fault = [rec[0] for rec in results if rec[1][1] == 'Timpa San Lorenzo thrust flat']

# %%
pprint(tsl_fault)
# Out:
# [Line with 9 points: (1122587.4318, 4446635.9005, 0.0000) ... (1122609.2299, 4446244.9876, 0.0000) - EPSG: 32632,
#  Line with 15 points: (1122597.1523, 4446198.9284, 0.0000) ... (1122969.2622, 4445578.3284, 0.0000) - EPSG: 32632,
#  Line with 9 points: (1123499.7739, 4444560.2654, 0.0000) ... (1124136.2790, 4443910.6815, 0.0000) - EPSG: 32632,
#  Line with 25 points: (1123581.1536, 4444598.4121, 0.0000) ... (1125254.0684, 4441887.4527, 0.0000) - EPSG: 32632,
#  Line with 21 points: (1125982.1256, 4440726.3395, 0.0000) ... (1126259.8433, 4438347.5446, 0.0000) - EPSG: 32632,
#  Line with 7 points: (1126782.4005, 4435581.1921, 0.0000) ... (1126770.1283, 4435195.3016, 0.0000) - EPSG: 32632,
#  Line with 4 points: (1126811.0355, 4435194.9607, 0.0000) ... (1126792.6273, 4435018.3782, 0.0000) - EPSG: 32632,
#  Line with 11 points: (1126813.0808, 4435028.6050, 0.0000) ... (1127426.0059, 4434574.5359, 0.0000) - EPSG: 32632,
#  Line with 6 points: (1127393.9620, 4434534.3106, 0.0000) ... (1127797.5790, 4434250.0061, 0.0000) - EPSG: 32632,
#  Line with 2 points: (1122587.6701, 4446733.3173, 0.0000) ... (1122594.0658, 4446635.2505, 0.0000) - EPSG: 32632,
#  Line with 2 points: (1122581.2744, 4446257.9067, 0.0000) ... (1122587.6701, 4446211.0052, 0.0000) - EPSG: 32632,
#  Line with 26 points: (1126415.4710, 4438302.7750, 0.0000) ... (1126856.2302, 4435551.1026, 0.0000) - EPSG: 32632,
#  Line with 12 points: (1121213.5295, 4449825.9619, 0.0000) ... (1121291.8739, 4448879.4208, 0.0000) - EPSG: 32632]

# %% [markdown]
# This is the set of line elements of the 'Timpa San Lorenzo thrust flat'.

# %% [markdown]
# ## Test of intersection with single line profile

# %%
base_profiler
# Out:
# LinearProfiler(
# 	start_pt = Point(1120743.2120, 4439367.3435, 0.0000, 0.0000, 32632),
# 	end_pt = Point(1128114.1749, 4444681.2936, 0.0000, 0.0000, 32632),
# 	densify_distance = 5.0)

# %%
topo_profile = base_profiler.profile_grid(geoarray)

# %% [markdown]
# We construct a geological profile object, empty for now.

# %%
geoprofile = GeoProfile()

# %% [markdown]
# Add the topographic profile to the geological profile and plot the former.

# %%
geoprofile.topo_profile = topo_profile
fig = plot(geoprofile)
# Out:
# Making topography

# %% [markdown]
# Now we try plotting the Timpa San Lorenzo flat intersection with the current profile.

# %%
pprint(tsl_fault)
# Out:
# [Line with 9 points: (1122587.4318, 4446635.9005, 0.0000) ... (1122609.2299, 4446244.9876, 0.0000) - EPSG: 32632,
#  Line with 15 points: (1122597.1523, 4446198.9284, 0.0000) ... (1122969.2622, 4445578.3284, 0.0000) - EPSG: 32632,
#  Line with 9 points: (1123499.7739, 4444560.2654, 0.0000) ... (1124136.2790, 4443910.6815, 0.0000) - EPSG: 32632,
#  Line with 25 points: (1123581.1536, 4444598.4121, 0.0000) ... (1125254.0684, 4441887.4527, 0.0000) - EPSG: 32632,
#  Line with 21 points: (1125982.1256, 4440726.3395, 0.0000) ... (1126259.8433, 4438347.5446, 0.0000) - EPSG: 32632,
#  Line with 7 points: (1126782.4005, 4435581.1921, 0.0000) ... (1126770.1283, 4435195.3016, 0.0000) - EPSG: 32632,
#  Line with 4 points: (1126811.0355, 4435194.9607, 0.0000) ... (1126792.6273, 4435018.3782, 0.0000) - EPSG: 32632,
#  Line with 11 points: (1126813.0808, 4435028.6050, 0.0000) ... (1127426.0059, 4434574.5359, 0.0000) - EPSG: 32632,
#  Line with 6 points: (1127393.9620, 4434534.3106, 0.0000) ... (1127797.5790, 4434250.0061, 0.0000) - EPSG: 32632,
#  Line with 2 points: (1122587.6701, 4446733.3173, 0.0000) ... (1122594.0658, 4446635.2505, 0.0000) - EPSG: 32632,
#  Line with 2 points: (1122581.2744, 4446257.9067, 0.0000) ... (1122587.6701, 4446211.0052, 0.0000) - EPSG: 32632,
#  Line with 26 points: (1126415.4710, 4438302.7750, 0.0000) ... (1126856.2302, 4435551.1026, 0.0000) - EPSG: 32632,
#  Line with 12 points: (1121213.5295, 4449825.9619, 0.0000) ... (1121291.8739, 4448879.4208, 0.0000) - EPSG: 32632]

# %%
line_intersections = base_profiler.intersect_lines(tsl_fault)

# %%
pprint(line_intersections)
# Out:
# [<pygsf.spatial.geology.profiles.elements.LineIntersections object at 0x7f527776f978>]

# %%
profile_intersections = base_profiler.parse_intersections_for_profile(line_intersections)

# %%
pprint(profile_intersections)
# Out:
# [<pygsf.spatial.geology.profiles.elements.ProfileSubpart object at 0x7f52773305c0>]

# %%
geoprofile.lines_intersections = profile_intersections

# %%
fig = plot(geoprofile)
# Out:
# Making topography

# %% [markdown]
# ## Analysing data with R

# %% [markdown]
# Help from:
#  - https://thomas-cokelaer.info/blog/2012/04/how-to-call-r-plotting-function-from-python-using-rpy2/

# %% [markdown]
# To close non-inline graphics:

# %%
try:
    r['dev.off']()
except:
    print("Already closed")
# Out:
# Already closed

# %% [markdown]
# The data arrays are extracted from the topographic profile,

# %%
s, z = topo_profile.s_arr(), topo_profile.z_arr()

# %% [markdown]
# Help from:
#  - https://blog.jupyter.org/i-python-you-r-we-julia-baf064ca1fb6
#
#  I Python, You R, We Julia
# Matthias Bussonnier
# Matthias Bussonnier
# May 29, 2018 · 8 min read

# %%
# %load_ext rpy2.ipython

# %%
# %Rpush s z

# %%
# %%R
# plot(s, z, type="l", col="blue", ylim=c(500, 2000))
# hist(z, col="orange")
