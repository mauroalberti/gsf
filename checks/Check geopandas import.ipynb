# %%
import os
import geopandas

# %%
src_data_fldr_pth = "/home/mauro/Documents/projects/gsf/example_data/timpa_san_lorenzo/"

# %%
src_data_faults_shpflnm = "faults.shp"

# %%
src_flpth = os.path.join(
    src_data_fldr_pth,
src_data_faults_shpflnm
)

# %%
print(src_flpth)
# Out:
# /home/mauro/Documents/projects/gsf/example_data/timpa_san_lorenzo/faults.shp

# %%
faults = geopandas.read_file(src_flpth)

# %%
print(faults)
# Out:
#      fid                                name      type  \
# 0    1.0                   Transversal fault  supposed
# 1    2.0                   Transversal fault   certain
# 2    3.0                   Transversal fault  supposed
# 3    4.0                   Transversal fault   certain
# 4    6.0       Timpa San Lorenzo thrust flat   certain
# 5    7.0       Timpa San Lorenzo thrust flat   certain
# 6    8.0                 Pollino minor fault      None
# 7    9.0                 Pollino minor fault      None
# 8   10.0       Timpa San Lorenzo thrust flat   certain
# 9   11.0       Timpa San Lorenzo thrust flat   certain
# 10  12.0       Timpa San Lorenzo thrust flat   certain
# 11  13.0  Timpa San Lorenzo flat minor fault  supposed
# 12  14.0       Timpa San Lorenzo thrust flat   certain
# 13  15.0  Timpa San Lorenzo flat minor fault  supposed
# 14  16.0       Timpa San Lorenzo thrust flat   certain
# 15  17.0  Timpa San Lorenzo flat minor fault  supposed
# ...

# %%
faults.plot(figsize=(20, 10))

# %%
type(faults)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
faults.geometry
# Out:
# 0     LINESTRING (1117773.775 4446200.667, 1118716.8...
# 1     LINESTRING (1121723.500 4443752.009, 1121967.6...
# 2     LINESTRING (1125995.931 4440726.430, 1126367.9...
# 3     LINESTRING (1127696.184 4439627.805, 1128024.6...
# 4     LINESTRING (1122587.432 4446635.901, 1122594.6...
# 5     LINESTRING (1122597.152 4446198.928, 1122629.2...
# 6     LINESTRING (1107560.898 4448750.318, 1107588.8...
# 7     LINESTRING (1107722.840 4448740.237, 1107751.1...
# 8     LINESTRING (1123499.774 4444560.265, 1123585.5...
# 9     LINESTRING (1123581.154 4444598.412, 1123666.8...
# 10    LINESTRING (1125982.126 4440726.339, 1125992.2...
# 11    LINESTRING (1126867.129 4435546.016, 1126779.9...
# 12    LINESTRING (1126782.400 4435581.192, 1126775.5...
# 13    LINESTRING (1126835.580 4435199.392, 1126760.5...
# 14    LINESTRING (1126811.035 4435194.961, 1126802.8...
# 15    LINESTRING (1126820.580 4435037.468, 1126784.4...
# 16    LINESTRING (1126813.081 4435028.605, 1126924.2...
# ...

# %%
for geom in faults.geometry:
    print type(geom)
# Out:
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# <class 'shapely.geometry.linestring.LineString'>
# ...

# %%
faults.attributes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-ad34601e34cb> in <module>()
# ----> 1 faults.attributes
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'GeoDataFrame' object has no attribute 'attributes'

# %%
for fault in faults:
    print(type(fault), fault)
# Out:
# (<type 'unicode'>, u'fid')
# (<type 'unicode'>, u'name')
# (<type 'unicode'>, u'type')
# (<type 'str'>, 'geometry')

# %%
faults
# Out:
#      fid                                name      type  \
# 0    1.0                   Transversal fault  supposed
# 1    2.0                   Transversal fault   certain
# 2    3.0                   Transversal fault  supposed
# 3    4.0                   Transversal fault   certain
# 4    6.0       Timpa San Lorenzo thrust flat   certain
# 5    7.0       Timpa San Lorenzo thrust flat   certain
# 6    8.0                 Pollino minor fault      None
# 7    9.0                 Pollino minor fault      None
# 8   10.0       Timpa San Lorenzo thrust flat   certain
# 9   11.0       Timpa San Lorenzo thrust flat   certain
# 10  12.0       Timpa San Lorenzo thrust flat   certain
# 11  13.0  Timpa San Lorenzo flat minor fault  supposed
# 12  14.0       Timpa San Lorenzo thrust flat   certain
# 13  15.0  Timpa San Lorenzo flat minor fault  supposed
# 14  16.0       Timpa San Lorenzo thrust flat   certain
# 15  17.0  Timpa San Lorenzo flat minor fault  supposed
# ...

# %%
type(faults)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
dir(faults)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__geo_interface__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__idiv__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

# %%
faults.values
# Out:
# array([[1.0, u'Transversal fault', u'supposed',
# ...
#        [2.0, u'Transversal fault', u'certain',
# ...
#        [3.0, u'Transversal fault', u'supposed',
# ...
#        [4.0, u'Transversal fault', u'certain',
# ...
#        [6.0, u'Timpa San Lorenzo thrust flat', u'certain',
# ...
#        [7.0, u'Timpa San Lorenzo thrust flat', u'certain',
# ...
#        [8.0, u'Pollino minor fault', None,
# ...
#        [9.0, u'Pollino minor fault', None,
# ...
#        [10.0, u'Timpa San Lorenzo thrust flat', u'certain',
# ...
#        [11.0, u'Timpa San Lorenzo thrust flat', u'certain',
# ...
#        [12.0, u'Timpa San Lorenzo thrust flat', u'certain',
# ...
#        [13.0, u'Timpa San Lorenzo flat minor fault', u'supposed',
# ...
#        [14.0, u'Timpa San Lorenzo thrust flat', u'certain',
# ...
#        [15.0, u'Timpa San Lorenzo flat minor fault', u'supposed',
# ...
#        [16.0, u'Timpa San Lorenzo thrust flat', u'certain',
# ...
#        [17.0, u'Timpa San Lorenzo flat minor fault', u'supposed',
# ...
#        [18.0, u'Timpa San Lorenzo thrust flat', u'certain',
# ...

# %%
faults.columns
# Out:
# Index([u'fid', u'name', u'type', u'geometry'], dtype='object')

# %%
type(faults.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
type(faults.values)
# Out:
# numpy.ndarray

# %%
list(faults.columns)
# Out:
# [u'fid', u'name', u'type', 'geometry']

# %%
len(faults)
# Out:
# 79

# %%
faults.schema
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-b63a16f974f7> in <module>()
# ----> 1 faults.schema
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'GeoDataFrame' object has no attribute 'schema'

# %%
dir(faults.geometry)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__geo_interface__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__idiv__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
# ...

# %%
set(faults.type)
# Out:
# {'LineString'}

# %%
faults.type
# Out:
# 0     LineString
# 1     LineString
# 2     LineString
# 3     LineString
# 4     LineString
# 5     LineString
# 6     LineString
# 7     LineString
# 8     LineString
# 9     LineString
# 10    LineString
# 11    LineString
# 12    LineString
# 13    LineString
# 14    LineString
# 15    LineString
# 16    LineString
# 17    LineString
# 18    LineString
# 19    LineString
# 20    LineString
# 21    LineString
# 22    LineString
# 23    LineString
# 24    LineString
# 25    LineString
# 26    LineString
# 27    LineString
# 28    LineString
# 29    LineString
#          ...
# 49    LineString
# 50    LineString
# 51    LineString
# 52    LineString
# 53    LineString
# 54    LineString
# 55    LineString
# 56    LineString
# 57    LineString
# 58    LineString
# 59    LineString
# 60    LineString
# 61    LineString
# 62    LineString
# 63    LineString
# 64    LineString
# 65    LineString
# 66    LineString
# 67    LineString
# 68    LineString
# 69    LineString
# ...

# %%
profile_src_pth = "/home/mauro/Documents/projects/gsf/example_data/timpa_san_lorenzo/profile.shp"

# %%
profile = geopandas.read_file(profile_src_pth)

# %%
profile
# Out:
#    id                                           geometry
# 0   1  LINESTRING (1120743.212 4439367.344, 1128114.1...

# %%
len(profile)
# Out:
# 1

# %%
profile[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-ab06c0c5ec87> in <module>()
# ----> 1 profile[0]
#
# /usr/local/lib/python2.7/dist-packages/geopandas/geodataframe.pyc in __getitem__(self, key)
#     555         GeoDataFrame.
#     556         """
# --> 557         result = super(GeoDataFrame, self).__getitem__(key)
#     558         geo_col = self._geometry_column_name
#     559         if isinstance(key, string_types) and key == geo_col:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ...

# %%
profile.geometry
# Out:
# 0    LINESTRING (1120743.212 4439367.344, 1128114.1...
# Name: geometry, dtype: geometry

# %%
geoms = profile.geometry

# %%
len(geoms)
# Out:
# 1

# %%
geoms[0]

# %%
type(geoms[0])
# Out:
# shapely.geometry.linestring.LineString

# %%
type(geoms)
# Out:
# geopandas.geoseries.GeoSeries

# %%
profile_geom = geoms[0]

# %%
profile_geom.xy
# Out:
# (array('d', [1120743.2119599984, 1128114.1749406955]),
#  array('d', [4439367.343520609, 4444681.29357646]))

# %%
x, y = profile_geom.xy

# %%
x
# Out:
# array('d', [1120743.2119599984, 1128114.1749406955])

# %%
y
# Out:
# array('d', [4439367.343520609, 4444681.29357646])

# %%
profile.crs
# Out:
# {u'init': u'epsg:32632'}

# %%
import geopandas

# %%
attitudes_fpth = "/home/mauro/Documents/projects/gSurf/example_data/mt_alpi/attitudes.shp"

# %%
attitudes = geopandas.read_file(attitudes_fpth)

# %%
type(attitudes)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
for att in attitudes:
    print(att)
# Out:
# Id
# dip_dir
# dip_ang
# Formation
# type
# geometry

# %%
for row in attitudes.values:
    print(row.Formation)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-5384fe846027> in <module>
#       1 for row in attitudes.values:
# ----> 2     print(row.Formation)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'Formation'

# %%
attitudes.columns
# Out:
# Index(['Id', 'dip_dir', 'dip_ang', 'Formation', 'type', 'geometry'], dtype='object')

# %%
attitudes['dip_dir']
# Out:
# 0      90.0
# 1      95.0
# 2      72.0
# 3      75.0
# 4      80.0
# 5      60.0
# 6      30.0
# 7      70.0
# 8     105.0
# 9     135.0
# 10     80.0
# Name: dip_dir, dtype: float64

# %%
attitudes.type
# Out:
# 0     Point
# 1     Point
# 2     Point
# 3     Point
# 4     Point
# 5     Point
# 6     Point
# 7     Point
# 8     Point
# 9     Point
# 10    Point
# dtype: object
